# %% [markdown]
# # Análise Inicial de Dados - Tênis de Corrida RunRepeat
#
# ## 1. Compreensão dos Atributos
#
# **Dataset:** 530 tênis de corrida extraídos do site RunRepeat
# **Período de coleta:** Novembro 2024
# **Total de atributos:** 46 colunas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Configurações de visualização
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)
sns.set_style('whitegrid')

# Carregar dados
df = pd.read_csv('tenis_scraper_runrepeat/dados_finais/runrepeat_shoes_complete.csv')

print(f"✅ Dataset carregado com sucesso!")
print(f"📊 Dimensões: {df.shape[0]} linhas x {df.shape[1]} colunas")
# Out:
# ✅ Dataset carregado com sucesso!
# 📊 Dimensões: 530 linhas x 46 colunas

# %% [markdown]
# ## 1.1 Visão Geral dos Dados

# %%
# Primeiras linhas do dataset
print("\n📋 PRIMEIRAS 5 LINHAS DO DATASET")
print("="*100)
display(df.head())
# Out:
# 📋 PRIMEIRAS 5 LINHAS DO DATASET
# ====================================================================================================
#                                name  \
# 0                 ASICS Novablast 5
# 1                  Nike Vomero Plus
# 2                      Hoka Bondi 9
# 3  New Balance Fresh Foam X More v5
# 4                    Nike Vomero 18
#
#                                                  url  \
# 0            https://runrepeat.com/asics-novablast-5
# 1             https://runrepeat.com/nike-vomero-plus
# 2                 https://runrepeat.com/hoka-bondi-9
# 3  https://runrepeat.com/new-balance-fresh-foam-x...
# 4               https://runrepeat.com/nike-vomero-18
#
#                                                image audience score price  \
# 0  https://cdn.runrepeat.com/storage/gallery/prod...     92 Superb!  $140
# 1  https://cdn.runrepeat.com/storage/gallery/prod...     91 Superb!  $180
# 2  https://cdn.runrepeat.com/storage/gallery/prod...      90 Great!  $170
# 3  https://cdn.runrepeat.com/storage/gallery/prod...      87 Great!  $155
# 4  https://cdn.runrepeat.com/storage/gallery/prod...     91 Superb!  $150
#
#                  pace arch support        weight lab weight brand lightweight  \
# 0  Daily runningTempo      Neutral        9 oz / 254g 9 oz / 255g           ✗
# 1       Daily running      Neutral  10.2 oz / 289g 10.1 oz / 285g         NaN
# 2       Daily running      Neutral  10.7 oz / 303g 10.5 oz / 297g         NaN
# 3       Daily running      Neutral  10.9 oz / 308g 10.7 oz / 303g         NaN
# 4       Daily running      Neutral  10.5 oz / 298g 11.5 oz / 325g         NaN
#
#   drop lab drop brand    strike pattern midsole softness  \
# 0       7.4 mm 8.0 mm  HeelMid/forefoot          13.0 HA
# 1      9.6 mm 10.0 mm  HeelMid/forefoot          15.1 HA
# 2       9.1 mm 5.0 mm  HeelMid/forefoot          25.1 HA
# 3       7.8 mm 4.0 mm      Mid/forefoot           8.6 HA
# 4     13.9 mm 10.0 mm              Heel          15.0 HA
#
#   difference in midsole softness in cold toebox durability  \
# 0                                    Big               Bad
# 1                                  Small            Decent
# 2                                  Small              Good
# 3                                 Normal            Decent
# 4                                  Small            Decent
#
#   heel padding durability outsole durability breathability heel stack  \
# 0                  Decent               Good      Moderate    40.9 mm
# 1                    Good               Good             3    42.3 mm
# 2                    Good               Good      Moderate    41.3 mm
# 3                  Decent               Good    Breathable    42.1 mm
# 4                    Good             Decent             3    42.5 mm
#
#   forefoot stack     drop flexibility / stiffness (new method)  \
# 0        33.5 mm   7.4 mm                                11.2N
# 1        32.7 mm   9.6 mm                                19.8N
# 2        32.2 mm   9.1 mm                                16.5N
# 3        34.3 mm   7.8 mm                                18.1N
# 4        28.6 mm  13.9 mm                                16.0N
#
#   flexibility / stiffness (old method)        brand  audience_score  \
# 0                                19.1N        ASICS            92.0
# 1                                  NaN         Nike            91.0
# 2                                30.6N         HOKA            90.0
# 3                                30.6N  New Balance            87.0
# 4                                  NaN         Nike            91.0
#
#    price_usd  drop_mm          weight  weight_grams trail terrain  \
# 0      140.0      7.4             NaN           NaN           NaN
# 1      180.0      9.6  10.2 oz (289g)         289.0           NaN
# 2      170.0      9.1  10.7 oz (303g)         303.0           NaN
# 3      155.0      7.8  10.9 oz (308g)         308.0           NaN
# 4      150.0     13.9  10.5 oz (298g)         298.0           NaN
#
#   heel stack lab heel stack brand midsole width - forefoot  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
#
#   midsole width - heel outsole thickness weight (g)  drop (mm)  \
# 0                  NaN               NaN        NaN        NaN
# 1                  NaN               NaN        NaN        NaN
# 2                  NaN               NaN        NaN        NaN
# 3                  NaN               NaN        NaN        NaN
# 4                  NaN               NaN        NaN        NaN
#
#    flexibility of the shoe (n)  flexibility of the shoe (freezer 20 min) (n)  \
# 0                          NaN                                           NaN
# 1                          NaN                                           NaN
# 2                          NaN                                           NaN
# 3                          NaN                                           NaN
# 4                          NaN                                           NaN
#
#   flexibility of the shoe (% of change)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    longitudinal flexibility (1-5 scale, 5 being the stiffest)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    torsional flexibility (1-5 scale, 5 being the stiffest)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    flexibility of the shoe (freezer 1 hour) (n)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    longitudinal flexibility (on a 0-5 scale, 0 being the stiffest)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    torsional flexibility (on a 0-5 scale, 0 being the stiffest)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   agility and responsiveness outsole hardness fuelcell supercomp pacer v2
# 0                        NaN              NaN                         NaN
# 1                        NaN              NaN                         NaN
# 2                        NaN              NaN                         NaN
# 3                        NaN              NaN                         NaN
# 4                        NaN              NaN                         NaN

# %%
# Informações gerais
print("\n📊 INFORMAÇÕES GERAIS DO DATASET")
print("="*100)
df.info()
# Out:
# 📊 INFORMAÇÕES GERAIS DO DATASET
# ====================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 46 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   name                                                             530 non-null    object
#  1   url                                                              530 non-null    object
#  2   image                                                            530 non-null    object
#  3   audience score                                                   521 non-null    object
#  4   price                                                            530 non-null    object
#  5   pace                                                             409 non-null    object
#  6   arch support                                                     530 non-null    object
#  7   weight lab weight brand                                          530 non-null    object
#  8   lightweight                                                      242 non-null    object
#  9   drop lab drop brand                                              530 non-null    object
#  10  strike pattern                                                   530 non-null    object
#  11  midsole softness                                                 530 non-null    object
#  12  difference in midsole softness in cold                           530 non-null    object
#  13  toebox durability                                                528 non-null    object
#  14  heel padding durability                                          530 non-null    object
#  15  outsole durability                                               528 non-null    object
#  16  breathability                                                    530 non-null    object
#  17  heel stack                                                       519 non-null    object
#  18  forefoot stack                                                   519 non-null    object
#  19  drop                                                             518 non-null    object
#  20  flexibility / stiffness (new method)                             311 non-null    object
#  21  flexibility / stiffness (old method)                             423 non-null    object
#  22  brand                                                            530 non-null    object
#  23  audience_score                                                   521 non-null    float64
#  24  price_usd                                                        530 non-null    float64
#  25  drop_mm                                                          518 non-null    float64
#  26  weight                                                           355 non-null    object
#  27  weight_grams                                                     355 non-null    float64
#  28  trail terrain                                                    121 non-null    object
#  29  heel stack lab heel stack brand                                  121 non-null    object
#  30  midsole width - forefoot                                         57 non-null     object
#  31  midsole width - heel                                             32 non-null     object
#  32  outsole thickness                                                11 non-null     object
#  33  weight (g)                                                       9 non-null      object
#  34  drop (mm)                                                        9 non-null      float64
#  35  flexibility of the shoe (n)                                      9 non-null      float64
#  36  flexibility of the shoe (freezer 20 min) (n)                     8 non-null      float64
#  37  flexibility of the shoe (% of change)                            9 non-null      object
#  38  longitudinal flexibility (1-5 scale, 5 being the stiffest)       8 non-null      float64
#  39  torsional flexibility (1-5 scale, 5 being the stiffest)          3 non-null      float64
#  40  flexibility of the shoe (freezer 1 hour) (n)                     1 non-null      float64
#  41  longitudinal flexibility (on a 0-5 scale, 0 being the stiffest)  1 non-null      float64
#  42  torsional flexibility (on a 0-5 scale, 0 being the stiffest)     1 non-null      float64
#  43  agility and responsiveness                                       1 non-null      object
#  44  outsole hardness                                                 2 non-null      object
#  45  fuelcell supercomp pacer v2                                      1 non-null      object
# dtypes: float64(12), object(34)
# memory usage: 190.6+ KB

# %% [markdown]
# ## 1.2 Classificação dos Atributos
#
# ### Definições:
#
# **Tipos de Atributos:**
# - **Nominal:** Categorias sem ordem (ex: marca, cor)
# - **Ordinal:** Categorias com ordem (ex: qualidade: ruim, bom, excelente)
# - **Numérico Discreto:** Valores inteiros contáveis (ex: número de reviews)
# - **Numérico Contínuo:** Valores reais em intervalo (ex: peso, preço)
#
# **Escalas Numéricas:**
# - **Intervalo:** Diferenças têm significado, mas razões não (ex: temperatura em Celsius)
# - **Razão:** Zero absoluto, razões têm significado (ex: peso, altura)
# - **Absoluta:** Contagens inteiras (ex: número de itens)

# %%
# Criar tabela de classificação dos atributos
atributos_classificacao = [
    # Atributos Identificadores e URLs
    {
        'Atributo': 'name',
        'Tipo': 'Nominal',
        'Domínio': 'Texto livre (nomes de produtos)',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['name'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Identificador único do produto. 530 valores únicos.'
    },
    {
        'Atributo': 'url',
        'Tipo': 'Nominal',
        'Domínio': 'URL válida (formato: https://runrepeat.com/...)',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['url'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Link para página do produto. Valores únicos.'
    },
    {
        'Atributo': 'image',
        'Tipo': 'Nominal',
        'Domínio': 'URL válida de imagem (CDN)',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['image'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'URL da imagem principal do produto.'
    },
    
    # Atributos de Avaliação
    {
        'Atributo': 'audience score',
        'Tipo': 'Ordinal',
        'Domínio': 'Texto: "XX Category" (ex: "92 Superb!")',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Intervalo',
        'Completude': f"{(df['audience score'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Score de 0-100 com categoria qualitativa. 23 valores únicos.'
    },
    {
        'Atributo': 'audience_score',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '[0, 100]',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['audience_score'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Versão numérica do score. Valor de referência zero.'
    },
    
    # Atributos de Preço
    {
        'Atributo': 'price',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "$XXX"',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['price'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Preço em formato texto. 43 valores únicos.'
    },
    {
        'Atributo': 'price_usd',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '[0, +∞) (valores reais positivos)',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'Razão',
        'Completude': f"{(df['price_usd'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Preço em USD. Zero absoluto (gratuito). Razão tem significado (2x mais caro).'
    },
    
    # Atributos de Marca
    {
        'Atributo': 'brand',
        'Tipo': 'Nominal',
        'Domínio': 'Texto (nomes de marcas)',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['brand'].notna().sum()/len(df)*100):.1f}%",
        'Observações': f'Fabricante do tênis. {df["brand"].nunique()} marcas diferentes.'
    },
    
    # Atributos de Uso/Tipo
    {
        'Atributo': 'pace',
        'Tipo': 'Ordinal',
        'Domínio': '{Daily running, Tempo, Racing, Walking, Hiking}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['pace'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Tipo de ritmo/uso recomendado. 5 categorias.'
    },
    {
        'Atributo': 'arch support',
        'Tipo': 'Ordinal',
        'Domínio': '{Neutral, Stability, Motion control}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['arch support'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Tipo de suporte ao arco do pé. 3 categorias ordenadas por nível de suporte.'
    },
    {
        'Atributo': 'strike pattern',
        'Tipo': 'Nominal',
        'Domínio': '{Heel, Mid/forefoot, HeelMid/forefoot}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['strike pattern'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Padrão de pisada recomendado. 3 categorias.'
    },
    {
        'Atributo': 'trail terrain',
        'Tipo': 'Ordinal',
        'Domínio': '{Light trail, Rugged terrain, Mountain/Ultra, etc}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['trail terrain'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Tipo de terreno (apenas para tênis de trail). Apenas 22.8% preenchido.'
    },
    
    # Atributos de Peso
    {
        'Atributo': 'weight',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX oz (XXXg)"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['weight'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Peso em formato texto com múltiplas unidades.'
    },
    {
        'Atributo': 'weight_grams',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '(0, +∞) gramas',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['weight_grams'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Peso em gramas. Zero absoluto. Razão tem significado (2x mais pesado).'
    },
    {
        'Atributo': 'weight lab weight brand',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX oz / XXXg XX oz / XXXg"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['weight lab weight brand'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Comparação peso laboratório vs. fabricante. 475 valores únicos.'
    },
    {
        'Atributo': 'lightweight',
        'Tipo': 'Nominal',
        'Domínio': '{✗, NaN}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['lightweight'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Indicador binário de leveza. Apenas 45.7% preenchido.'
    },
    {
        'Atributo': 'weight (g)',
        'Tipo': 'Nominal',
        'Domínio': 'Texto numérico',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['weight (g)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Peso alternativo. Apenas 1.7% preenchido. Redundante com weight_grams.'
    },
    
    # Atributos de Drop
    {
        'Atributo': 'drop',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['drop'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Diferença de altura calcanhar-antepé em formato texto. 134 valores únicos.'
    },
    {
        'Atributo': 'drop_mm',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '[0, +∞) milímetros',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['drop_mm'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Drop em mm. Zero significa "zero drop". Razão tem significado.'
    },
    {
        'Atributo': 'drop lab drop brand',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm XX mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['drop lab drop brand'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Comparação drop laboratório vs. fabricante. 313 valores únicos.'
    },
    {
        'Atributo': 'drop (mm)',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '[0, +∞) milímetros',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['drop (mm)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Drop alternativo. Apenas 1.7% preenchido. Redundante com drop_mm.'
    },
    
    # Atributos de Stack (Altura da Sola)
    {
        'Atributo': 'heel stack',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm" ou "XX.X mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['heel stack'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Altura da sola no calcanhar em formato texto. 176 valores únicos.'
    },
    {
        'Atributo': 'forefoot stack',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm" ou "XX.X mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['forefoot stack'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Altura da sola no antepé em formato texto. 177 valores únicos.'
    },
    {
        'Atributo': 'heel stack lab heel stack brand',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX.X mm XX.X mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['heel stack lab heel stack brand'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Comparação stack laboratório vs. fabricante. Apenas 22.8% preenchido.'
    },
    
    # Atributos de Maciez/Amortecimento
    {
        'Atributo': 'midsole softness',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX HA" ou "XX.X HA"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['midsole softness'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Dureza Shore A. Valores maiores = mais duro. 175 valores únicos.'
    },
    {
        'Atributo': 'difference in midsole softness in cold',
        'Tipo': 'Ordinal',
        'Domínio': '{Small, Big, Huge, Medium, Moderate}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['difference in midsole softness in cold'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Mudança na maciez em temperatura fria. 5 categorias ordenadas.'
    },
    
    # Atributos de Flexibilidade
    {
        'Atributo': 'flexibility / stiffness (new method)',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX N" ou "XX.X N"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['flexibility / stiffness (new method)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Rigidez em Newtons (novo método). 133 valores únicos. 58.7% preenchido.'
    },
    {
        'Atributo': 'flexibility / stiffness (old method)',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX N" ou "XX.X N"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['flexibility / stiffness (old method)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Rigidez em Newtons (método antigo). 242 valores únicos. 79.8% preenchido.'
    },
    {
        'Atributo': 'flexibility of the shoe (n)',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '(0, +∞) Newtons',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['flexibility of the shoe (n)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Força necessária para dobrar. Apenas 1.7% preenchido.'
    },
    {
        'Atributo': 'flexibility of the shoe (freezer 20 min) (n)',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '(0, +∞) Newtons',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['flexibility of the shoe (freezer 20 min) (n)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade após congelamento. Apenas 1.5% preenchido.'
    },
    {
        'Atributo': 'flexibility of the shoe (freezer 1 hour) (n)',
        'Tipo': 'Numérico Contínuo',
        'Domínio': '(0, +∞) Newtons',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Razão',
        'Completude': f"{(df['flexibility of the shoe (freezer 1 hour) (n)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade após 1h congelamento. Apenas 0.2% preenchido.'
    },
    {
        'Atributo': 'flexibility of the shoe (% of change)',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX%" ou "-XX%"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['flexibility of the shoe (% of change)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Variação percentual na flexibilidade. Apenas 1.7% preenchido.'
    },
    {
        'Atributo': 'longitudinal flexibility (1-5 scale, 5 being the stiffest)',
        'Tipo': 'Ordinal',
        'Domínio': '[1, 5] (escala discreta)',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Intervalo',
        'Completude': f"{(df['longitudinal flexibility (1-5 scale, 5 being the stiffest)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade longitudinal. Escala ordinal. Apenas 1.5% preenchido.'
    },
    {
        'Atributo': 'longitudinal flexibility (on a 0-5 scale, 0 being the stiffest)',
        'Tipo': 'Ordinal',
        'Domínio': '[0, 5] (escala discreta)',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Intervalo',
        'Completude': f"{(df['longitudinal flexibility (on a 0-5 scale, 0 being the stiffest)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade longitudinal (escala invertida). Apenas 0.2% preenchido.'
    },
    {
        'Atributo': 'torsional flexibility (1-5 scale, 5 being the stiffest)',
        'Tipo': 'Ordinal',
        'Domínio': '[1, 5] (escala discreta)',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Intervalo',
        'Completude': f"{(df['torsional flexibility (1-5 scale, 5 being the stiffest)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade torsional. Apenas 0.6% preenchido.'
    },
    {
        'Atributo': 'torsional flexibility (on a 0-5 scale, 0 being the stiffest)',
        'Tipo': 'Ordinal',
        'Domínio': '[0, 5] (escala discreta)',
        'Domínio Dinâmico': 'Não',
        'Escala': 'Intervalo',
        'Completude': f"{(df['torsional flexibility (on a 0-5 scale, 0 being the stiffest)'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Flexibilidade torsional (escala invertida). Apenas 0.2% preenchido.'
    },
    
    # Atributos de Durabilidade
    {
        'Atributo': 'toebox durability',
        'Tipo': 'Ordinal',
        'Domínio': '{Bad, Decent, Good, Great, Excellent, Outstanding}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['toebox durability'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Durabilidade da parte frontal. 6 categorias ordenadas por qualidade.'
    },
    {
        'Atributo': 'heel padding durability',
        'Tipo': 'Ordinal',
        'Domínio': '{Bad, Decent, Good, Great}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['heel padding durability'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Durabilidade do acolchoamento do calcanhar. 4 categorias ordenadas.'
    },
    {
        'Atributo': 'outsole durability',
        'Tipo': 'Ordinal',
        'Domínio': '{Bad, Decent, Good, Great}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['outsole durability'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Durabilidade da sola externa. 4 categorias ordenadas.'
    },
    {
        'Atributo': 'outsole hardness',
        'Tipo': 'Nominal',
        'Domínio': 'Texto livre',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['outsole hardness'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Dureza da sola. Apenas 0.4% preenchido.'
    },
    
    # Atributos de Respirabilidade
    {
        'Atributo': 'breathability',
        'Tipo': 'Ordinal',
        'Domínio': '{Poor, Moderate, Good, Excellent, etc}',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['breathability'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Capacidade de ventilação. 9 valores únicos ordenados.'
    },
    
    # Atributos de Largura
    {
        'Atributo': 'midsole width - forefoot',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm" ou "XXX mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['midsole width - forefoot'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Largura da entressola no antepé. Apenas 10.8% preenchido.'
    },
    {
        'Atributo': 'midsole width - heel',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "XX mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['midsole width - heel'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Largura da entressola no calcanhar. Apenas 6.0% preenchido.'
    },
    
    # Atributos de Espessura
    {
        'Atributo': 'outsole thickness',
        'Tipo': 'Nominal',
        'Domínio': 'Texto: "X.X mm"',
        'Domínio Dinâmico': 'Não',
        'Escala': 'N/A',
        'Completude': f"{(df['outsole thickness'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Espessura da sola externa. Apenas 2.1% preenchido.'
    },
    
    # Atributos Diversos/Esparsos
    {
        'Atributo': 'agility and responsiveness',
        'Tipo': 'Nominal',
        'Domínio': 'Texto livre',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['agility and responsiveness'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Avaliação de agilidade. Apenas 0.2% preenchido.'
    },
    {
        'Atributo': 'fuelcell supercomp pacer v2',
        'Tipo': 'Nominal',
        'Domínio': 'Texto livre',
        'Domínio Dinâmico': 'Sim',
        'Escala': 'N/A',
        'Completude': f"{(df['fuelcell supercomp pacer v2'].notna().sum()/len(df)*100):.1f}%",
        'Observações': 'Atributo específico de produto. Apenas 0.2% preenchido. Erro de extração.'
    },
]

# Criar DataFrame
df_atributos = pd.DataFrame(atributos_classificacao)

# Exibir tabela
print("\n📋 TABELA DE CLASSIFICAÇÃO DOS ATRIBUTOS")
print("="*120)
display(df_atributos)
# Out:
# 📋 TABELA DE CLASSIFICAÇÃO DOS ATRIBUTOS
# ========================================================================================================================
#                                              Atributo               Tipo  \
# 0                                                name            Nominal
# 1                                                 url            Nominal
# 2                                               image            Nominal
# 3                                      audience score            Ordinal
# 4                                      audience_score  Numérico Contínuo
# 5                                               price            Nominal
# 6                                           price_usd  Numérico Contínuo
# 7                                               brand            Nominal
# 8                                                pace            Ordinal
# 9                                        arch support            Ordinal
# 10                                     strike pattern            Nominal
# 11                                      trail terrain            Ordinal
# 12                                             weight            Nominal
# 13                                       weight_grams  Numérico Contínuo
# 14                            weight lab weight brand            Nominal
# 15                                        lightweight            Nominal
# 16                                         weight (g)            Nominal
# 17                                               drop            Nominal
# 18                                            drop_mm  Numérico Contínuo
# 19                                drop lab drop brand            Nominal
# 20                                          drop (mm)  Numérico Contínuo
# 21                                         heel stack            Nominal
# 22                                     forefoot stack            Nominal
# 23                    heel stack lab heel stack brand            Nominal
# 24                                   midsole softness            Nominal
# 25             difference in midsole softness in cold            Ordinal
# 26               flexibility / stiffness (new method)            Nominal
# 27               flexibility / stiffness (old method)            Nominal
# 28                        flexibility of the shoe (n)  Numérico Contínuo
# 29       flexibility of the shoe (freezer 20 min) (n)  Numérico Contínuo
# 30       flexibility of the shoe (freezer 1 hour) (n)  Numérico Contínuo
# 31              flexibility of the shoe (% of change)            Nominal
# 32  longitudinal flexibility (1-5 scale, 5 being t...            Ordinal
# 33  longitudinal flexibility (on a 0-5 scale, 0 be...            Ordinal
# 34  torsional flexibility (1-5 scale, 5 being the ...            Ordinal
# 35  torsional flexibility (on a 0-5 scale, 0 being...            Ordinal
# 36                                  toebox durability            Ordinal
# 37                            heel padding durability            Ordinal
# 38                                 outsole durability            Ordinal
# 39                                   outsole hardness            Nominal
# 40                                      breathability            Ordinal
# 41                           midsole width - forefoot            Nominal
# 42                               midsole width - heel            Nominal
# 43                                  outsole thickness            Nominal
# 44                         agility and responsiveness            Nominal
# 45                        fuelcell supercomp pacer v2            Nominal
#
#                                               Domínio Domínio Dinâmico  \
# 0                     Texto livre (nomes de produtos)              Sim
# 1     URL válida (formato: https://runrepeat.com/...)              Sim
# 2                          URL válida de imagem (CDN)              Sim
# 3             Texto: "XX Category" (ex: "92 Superb!")              Não
# 4                                            [0, 100]              Não
# 5                                       Texto: "$XXX"              Sim
# 6                   [0, +∞) (valores reais positivos)              Sim
# 7                             Texto (nomes de marcas)              Sim
# 8     {Daily running, Tempo, Racing, Walking, Hiking}              Não
# 9                {Neutral, Stability, Motion control}              Não
# 10             {Heel, Mid/forefoot, HeelMid/forefoot}              Não
# 11  {Light trail, Rugged terrain, Mountain/Ultra, ...              Não
# 12                              Texto: "XX oz (XXXg)"              Não
# 13                                     (0, +∞) gramas              Não
# 14                 Texto: "XX oz / XXXg XX oz / XXXg"              Não
# 15                                           {✗, NaN}              Não
# 16                                     Texto numérico              Não
# 17                                     Texto: "XX mm"              Não
# 18                                 [0, +∞) milímetros              Não
# 19                               Texto: "XX mm XX mm"              Não
# 20                                 [0, +∞) milímetros              Não
# 21                        Texto: "XX mm" ou "XX.X mm"              Não
# 22                        Texto: "XX mm" ou "XX.X mm"              Não
# 23                           Texto: "XX.X mm XX.X mm"              Não
# 24                        Texto: "XX HA" ou "XX.X HA"              Não
# 25               {Small, Big, Huge, Medium, Moderate}              Não
# 26                          Texto: "XX N" ou "XX.X N"              Não
# 27                          Texto: "XX N" ou "XX.X N"              Não
# 28                                    (0, +∞) Newtons              Não
# 29                                    (0, +∞) Newtons              Não
# 30                                    (0, +∞) Newtons              Não
# 31                             Texto: "XX%" ou "-XX%"              Não
# 32                           [1, 5] (escala discreta)              Não
# 33                           [0, 5] (escala discreta)              Não
# 34                           [1, 5] (escala discreta)              Não
# 35                           [0, 5] (escala discreta)              Não
# 36  {Bad, Decent, Good, Great, Excellent, Outstand...              Não
# 37                         {Bad, Decent, Good, Great}              Não
# 38                         {Bad, Decent, Good, Great}              Não
# 39                                        Texto livre              Não
# 40             {Poor, Moderate, Good, Excellent, etc}              Não
# 41                         Texto: "XX mm" ou "XXX mm"              Não
# 42                                     Texto: "XX mm"              Não
# 43                                    Texto: "X.X mm"              Não
# 44                                        Texto livre              Sim
# 45                                        Texto livre              Sim
#
#        Escala Completude                                        Observações
# 0         N/A     100.0%  Identificador único do produto. 530 valores ún...
# 1         N/A     100.0%       Link para página do produto. Valores únicos.
# 2         N/A     100.0%                URL da imagem principal do produto.
# 3   Intervalo      98.3%  Score de 0-100 com categoria qualitativa. 23 v...
# 4       Razão      98.3%  Versão numérica do score. Valor de referência ...
# 5         N/A     100.0%         Preço em formato texto. 43 valores únicos.
# 6       Razão     100.0%  Preço em USD. Zero absoluto (gratuito). Razão ...
# 7         N/A     100.0%         Fabricante do tênis. 26 marcas diferentes.
# 8         N/A      77.2%       Tipo de ritmo/uso recomendado. 5 categorias.
# 9         N/A     100.0%  Tipo de suporte ao arco do pé. 3 categorias or...
# 10        N/A     100.0%        Padrão de pisada recomendado. 3 categorias.
# 11        N/A      22.8%  Tipo de terreno (apenas para tênis de trail). ...
# 12        N/A      67.0%      Peso em formato texto com múltiplas unidades.
# 13      Razão      67.0%  Peso em gramas. Zero absoluto. Razão tem signi...
# 14        N/A     100.0%  Comparação peso laboratório vs. fabricante. 47...
# 15        N/A      45.7%  Indicador binário de leveza. Apenas 45.7% pree...
# 16        N/A       1.7%  Peso alternativo. Apenas 1.7% preenchido. Redu...
# 17        N/A      97.7%  Diferença de altura calcanhar-antepé em format...
# 18      Razão      97.7%  Drop em mm. Zero significa "zero drop". Razão ...
# 19        N/A     100.0%  Comparação drop laboratório vs. fabricante. 31...
# 20      Razão       1.7%  Drop alternativo. Apenas 1.7% preenchido. Redu...
# 21        N/A      97.9%  Altura da sola no calcanhar em formato texto. ...
# 22        N/A      97.9%  Altura da sola no antepé em formato texto. 177...
# 23        N/A      22.8%  Comparação stack laboratório vs. fabricante. A...
# 24        N/A     100.0%  Dureza Shore A. Valores maiores = mais duro. 1...
# 25        N/A     100.0%  Mudança na maciez em temperatura fria. 5 categ...
# 26        N/A      58.7%  Rigidez em Newtons (novo método). 133 valores ...
# 27        N/A      79.8%  Rigidez em Newtons (método antigo). 242 valore...
# 28      Razão       1.7%  Força necessária para dobrar. Apenas 1.7% pree...
# 29      Razão       1.5%  Flexibilidade após congelamento. Apenas 1.5% p...
# 30      Razão       0.2%  Flexibilidade após 1h congelamento. Apenas 0.2...
# 31        N/A       1.7%  Variação percentual na flexibilidade. Apenas 1...
# 32  Intervalo       1.5%  Flexibilidade longitudinal. Escala ordinal. Ap...
# 33  Intervalo       0.2%  Flexibilidade longitudinal (escala invertida)....
# 34  Intervalo       0.6%   Flexibilidade torsional. Apenas 0.6% preenchido.
# 35  Intervalo       0.2%  Flexibilidade torsional (escala invertida). Ap...
# 36        N/A      99.6%  Durabilidade da parte frontal. 6 categorias or...
# 37        N/A     100.0%  Durabilidade do acolchoamento do calcanhar. 4 ...
# 38        N/A      99.6%  Durabilidade da sola externa. 4 categorias ord...
# 39        N/A       0.4%            Dureza da sola. Apenas 0.4% preenchido.
# 40        N/A     100.0%  Capacidade de ventilação. 9 valores únicos ord...
# 41        N/A      10.8%  Largura da entressola no antepé. Apenas 10.8% ...
# 42        N/A       6.0%  Largura da entressola no calcanhar. Apenas 6.0...
# 43        N/A       2.1%  Espessura da sola externa. Apenas 2.1% preench...
# 44        N/A       0.2%    Avaliação de agilidade. Apenas 0.2% preenchido.
# 45        N/A       0.2%  Atributo específico de produto. Apenas 0.2% pr...

# %% [markdown]
# ## 1.3 Estatísticas de Completude dos Dados

# %%
# Calcular estatísticas de completude
completude = pd.DataFrame({
    'Atributo': df.columns,
    'Total': len(df),
    'Não-Nulos': df.notna().sum(),
    'Nulos': df.isna().sum(),
    'Completude (%)': (df.notna().sum() / len(df) * 100).round(1),
    'Valores Únicos': df.nunique()
})

completude = completude.sort_values('Completude (%)', ascending=False)

print("\n📊 ESTATÍSTICAS DE COMPLETUDE POR ATRIBUTO")
print("="*100)
display(completude)
# Out:
# 📊 ESTATÍSTICAS DE COMPLETUDE POR ATRIBUTO
# ====================================================================================================
#                                                                                              Atributo  \
# name                                                                                             name
# breathability                                                                           breathability
# image                                                                                           image
# price_usd                                                                                   price_usd
# price                                                                                           price
# url                                                                                               url
# arch support                                                                             arch support
# weight lab weight brand                                                       weight lab weight brand
# brand                                                                                           brand
# drop lab drop brand                                                               drop lab drop brand
# strike pattern                                                                         strike pattern
# midsole softness                                                                     midsole softness
# difference in midsole softness in cold                         difference in midsole softness in cold
# heel padding durability                                                       heel padding durability
# toebox durability                                                                   toebox durability
# outsole durability                                                                 outsole durability
# audience_score                                                                         audience_score
# audience score                                                                         audience score
# heel stack                                                                                 heel stack
# forefoot stack                                                                         forefoot stack
# drop                                                                                             drop
# drop_mm                                                                                       drop_mm
# flexibility / stiffness (old method)                             flexibility / stiffness (old method)
# pace                                                                                             pace
# weight                                                                                         weight
# weight_grams                                                                             weight_grams
# flexibility / stiffness (new method)                             flexibility / stiffness (new method)
# lightweight                                                                               lightweight
# trail terrain                                                                           trail terrain
# heel stack lab heel stack brand                                       heel stack lab heel stack brand
# midsole width - forefoot                                                     midsole width - forefoot
# midsole width - heel                                                             midsole width - heel
# outsole thickness                                                                   outsole thickness
# weight (g)                                                                                 weight (g)
# drop (mm)                                                                                   drop (mm)
# flexibility of the shoe (n)                                               flexibility of the shoe (n)
# flexibility of the shoe (% of change)                           flexibility of the shoe (% of change)
# flexibility of the shoe (freezer 20 min) (n)             flexibility of the shoe (freezer 20 min) (n)
# longitudinal flexibility (1-5 scale, 5 being th...  longitudinal flexibility (1-5 scale, 5 being t...
# torsional flexibility (1-5 scale, 5 being the s...  torsional flexibility (1-5 scale, 5 being the ...
# outsole hardness                                                                     outsole hardness
# flexibility of the shoe (freezer 1 hour) (n)             flexibility of the shoe (freezer 1 hour) (n)
# longitudinal flexibility (on a 0-5 scale, 0 bei...  longitudinal flexibility (on a 0-5 scale, 0 be...
# torsional flexibility (on a 0-5 scale, 0 being ...  torsional flexibility (on a 0-5 scale, 0 being...
# agility and responsiveness                                                 agility and responsiveness
# fuelcell supercomp pacer v2                                               fuelcell supercomp pacer v2
#
#                                                     Total  Não-Nulos  Nulos  \
# name                                                  530        530      0
# breathability                                         530        530      0
# image                                                 530        530      0
# price_usd                                             530        530      0
# price                                                 530        530      0
# url                                                   530        530      0
# arch support                                          530        530      0
# weight lab weight brand                               530        530      0
# brand                                                 530        530      0
# drop lab drop brand                                   530        530      0
# strike pattern                                        530        530      0
# midsole softness                                      530        530      0
# difference in midsole softness in cold                530        530      0
# heel padding durability                               530        530      0
# toebox durability                                     530        528      2
# outsole durability                                    530        528      2
# audience_score                                        530        521      9
# audience score                                        530        521      9
# heel stack                                            530        519     11
# forefoot stack                                        530        519     11
# drop                                                  530        518     12
# drop_mm                                               530        518     12
# flexibility / stiffness (old method)                  530        423    107
# pace                                                  530        409    121
# weight                                                530        355    175
# weight_grams                                          530        355    175
# flexibility / stiffness (new method)                  530        311    219
# lightweight                                           530        242    288
# trail terrain                                         530        121    409
# heel stack lab heel stack brand                       530        121    409
# midsole width - forefoot                              530         57    473
# midsole width - heel                                  530         32    498
# outsole thickness                                     530         11    519
# weight (g)                                            530          9    521
# drop (mm)                                             530          9    521
# flexibility of the shoe (n)                           530          9    521
# flexibility of the shoe (% of change)                 530          9    521
# flexibility of the shoe (freezer 20 min) (n)          530          8    522
# longitudinal flexibility (1-5 scale, 5 being th...    530          8    522
# torsional flexibility (1-5 scale, 5 being the s...    530          3    527
# outsole hardness                                      530          2    528
# flexibility of the shoe (freezer 1 hour) (n)          530          1    529
# longitudinal flexibility (on a 0-5 scale, 0 bei...    530          1    529
# torsional flexibility (on a 0-5 scale, 0 being ...    530          1    529
# agility and responsiveness                            530          1    529
# fuelcell supercomp pacer v2                           530          1    529
#
#                                                     Completude (%)  \
# name                                                         100.0
# breathability                                                100.0
# image                                                        100.0
# price_usd                                                    100.0
# price                                                        100.0
# url                                                          100.0
# arch support                                                 100.0
# weight lab weight brand                                      100.0
# brand                                                        100.0
# drop lab drop brand                                          100.0
# strike pattern                                               100.0
# midsole softness                                             100.0
# difference in midsole softness in cold                       100.0
# heel padding durability                                      100.0
# toebox durability                                             99.6
# outsole durability                                            99.6
# audience_score                                                98.3
# audience score                                                98.3
# heel stack                                                    97.9
# forefoot stack                                                97.9
# drop                                                          97.7
# drop_mm                                                       97.7
# flexibility / stiffness (old method)                          79.8
# pace                                                          77.2
# weight                                                        67.0
# weight_grams                                                  67.0
# flexibility / stiffness (new method)                          58.7
# lightweight                                                   45.7
# trail terrain                                                 22.8
# heel stack lab heel stack brand                               22.8
# midsole width - forefoot                                      10.8
# midsole width - heel                                           6.0
# outsole thickness                                              2.1
# weight (g)                                                     1.7
# drop (mm)                                                      1.7
# flexibility of the shoe (n)                                    1.7
# flexibility of the shoe (% of change)                          1.7
# flexibility of the shoe (freezer 20 min) (n)                   1.5
# longitudinal flexibility (1-5 scale, 5 being th...             1.5
# torsional flexibility (1-5 scale, 5 being the s...             0.6
# outsole hardness                                               0.4
# flexibility of the shoe (freezer 1 hour) (n)                   0.2
# longitudinal flexibility (on a 0-5 scale, 0 bei...             0.2
# torsional flexibility (on a 0-5 scale, 0 being ...             0.2
# agility and responsiveness                                     0.2
# fuelcell supercomp pacer v2                                    0.2
#
#                                                     Valores Únicos
# name                                                           530
# breathability                                                    9
# image                                                          530
# price_usd                                                       43
# price                                                           43
# url                                                            530
# arch support                                                     3
# weight lab weight brand                                        475
# brand                                                           26
# drop lab drop brand                                            313
# strike pattern                                                   3
# midsole softness                                               175
# difference in midsole softness in cold                           5
# heel padding durability                                          4
# toebox durability                                                6
# outsole durability                                               4
# audience_score                                                  23
# audience score                                                  23
# heel stack                                                     176
# forefoot stack                                                 177
# drop                                                           134
# drop_mm                                                        132
# flexibility / stiffness (old method)                           242
# pace                                                             5
# weight                                                         128
# weight_grams                                                   128
# flexibility / stiffness (new method)                           133
# lightweight                                                      2
# trail terrain                                                    5
# heel stack lab heel stack brand                                119
# midsole width - forefoot                                        48
# midsole width - heel                                            29
# outsole thickness                                               10
# weight (g)                                                       9
# drop (mm)                                                        8
# flexibility of the shoe (n)                                      9
# flexibility of the shoe (% of change)                            9
# flexibility of the shoe (freezer 20 min) (n)                     8
# longitudinal flexibility (1-5 scale, 5 being th...               3
# torsional flexibility (1-5 scale, 5 being the s...               1
# outsole hardness                                                 2
# flexibility of the shoe (freezer 1 hour) (n)                     1
# longitudinal flexibility (on a 0-5 scale, 0 bei...               1
# torsional flexibility (on a 0-5 scale, 0 being ...               1
# agility and responsiveness                                       1
# fuelcell supercomp pacer v2                                      1

# %%
# Visualizar completude
fig, ax = plt.subplots(figsize=(12, 10))

# Filtrar atributos com menos de 100% de completude
completude_parcial = completude[completude['Completude (%)'] < 100].sort_values('Completude (%)')

colors = ['red' if x < 50 else 'orange' if x < 80 else 'yellow' for x in completude_parcial['Completude (%)']]

ax.barh(completude_parcial['Atributo'], completude_parcial['Completude (%)'], color=colors)
ax.set_xlabel('Completude (%)', fontsize=12)
ax.set_title('Completude dos Atributos (< 100%)', fontsize=14, fontweight='bold')
ax.axvline(x=50, color='red', linestyle='--', alpha=0.5, label='50%')
ax.axvline(x=80, color='orange', linestyle='--', alpha=0.5, label='80%')
ax.legend()
ax.grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n⚠️  Atributos com menos de 50% de dados: {len(completude[completude['Completude (%)'] < 50])}")
print(f"⚠️  Atributos com 50-80% de dados: {len(completude[(completude['Completude (%)'] >= 50) & (completude['Completude (%)'] < 80)])}")
print(f"✅ Atributos com 80-100% de dados: {len(completude[(completude['Completude (%)'] >= 80) & (completude['Completude (%)'] < 100)])}")
print(f"✅ Atributos com 100% de dados: {len(completude[completude['Completude (%)'] == 100])}")
# Out:
# ⚠️  Atributos com menos de 50% de dados: 19
# ⚠️  Atributos com 50-80% de dados: 5
# ✅ Atributos com 80-100% de dados: 8
# ✅ Atributos com 100% de dados: 14

# %% [markdown]
# ## 1.4 Análise por Tipo de Atributo

# %%
# Contar atributos por tipo
tipo_counts = df_atributos['Tipo'].value_counts()

print("\n📊 DISTRIBUIÇÃO POR TIPO DE ATRIBUTO")
print("="*60)
for tipo, count in tipo_counts.items():
    print(f"{tipo:25s}: {count:2d} atributos ({count/len(df_atributos)*100:.1f}%)")

# Gráfico de pizza
fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(tipo_counts.values, labels=tipo_counts.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Distribuição dos Atributos por Tipo', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# 📊 DISTRIBUIÇÃO POR TIPO DE ATRIBUTO
# ============================================================
# Nominal                  : 25 atributos (54.3%)
# Ordinal                  : 13 atributos (28.3%)
# Numérico Contínuo        :  8 atributos (17.4%)

# %% [markdown]
# ## 1.5 Análise de Atributos Numéricos

# %%
# Filtrar apenas atributos numéricos
atributos_numericos = df_atributos[df_atributos['Tipo'].isin(['Numérico Contínuo', 'Numérico Discreto'])]

print("\n🔢 ATRIBUTOS NUMÉRICOS E SUAS ESCALAS")
print("="*100)
display(atributos_numericos[['Atributo', 'Tipo', 'Escala', 'Domínio', 'Completude', 'Observações']])
# Out:
# 🔢 ATRIBUTOS NUMÉRICOS E SUAS ESCALAS
# ====================================================================================================
#                                         Atributo               Tipo Escala  \
# 4                                 audience_score  Numérico Contínuo  Razão
# 6                                      price_usd  Numérico Contínuo  Razão
# 13                                  weight_grams  Numérico Contínuo  Razão
# 18                                       drop_mm  Numérico Contínuo  Razão
# 20                                     drop (mm)  Numérico Contínuo  Razão
# 28                   flexibility of the shoe (n)  Numérico Contínuo  Razão
# 29  flexibility of the shoe (freezer 20 min) (n)  Numérico Contínuo  Razão
# 30  flexibility of the shoe (freezer 1 hour) (n)  Numérico Contínuo  Razão
#
#                               Domínio Completude  \
# 4                            [0, 100]      98.3%
# 6   [0, +∞) (valores reais positivos)     100.0%
# 13                     (0, +∞) gramas      67.0%
# 18                 [0, +∞) milímetros      97.7%
# 20                 [0, +∞) milímetros       1.7%
# 28                    (0, +∞) Newtons       1.7%
# 29                    (0, +∞) Newtons       1.5%
# 30                    (0, +∞) Newtons       0.2%
#
#                                           Observações
# 4   Versão numérica do score. Valor de referência ...
# 6   Preço em USD. Zero absoluto (gratuito). Razão ...
# 13  Peso em gramas. Zero absoluto. Razão tem signi...
# 18  Drop em mm. Zero significa "zero drop". Razão ...
# 20  Drop alternativo. Apenas 1.7% preenchido. Redu...
# 28  Força necessária para dobrar. Apenas 1.7% pree...
# 29  Flexibilidade após congelamento. Apenas 1.5% p...
# 30  Flexibilidade após 1h congelamento. Apenas 0.2...

# %%
# Estatísticas descritivas dos principais atributos numéricos
principais_numericos = ['audience_score', 'price_usd', 'weight_grams', 'drop_mm']
colunas_existentes = [col for col in principais_numericos if col in df.columns]

if colunas_existentes:
    print("\n📈 ESTATÍSTICAS DESCRITIVAS DOS PRINCIPAIS ATRIBUTOS NUMÉRICOS")
    print("="*100)
    display(df[colunas_existentes].describe().round(2))
# Out:
# 📈 ESTATÍSTICAS DESCRITIVAS DOS PRINCIPAIS ATRIBUTOS NUMÉRICOS
# ====================================================================================================
#        audience_score  price_usd  weight_grams  drop_mm
# count          521.00     530.00        355.00   518.00
# mean            86.78     154.53        273.95     8.32
# std              3.77      55.62         38.83     3.16
# min             70.00      65.00        128.00     0.00
# 25%             85.00     130.00        257.00     6.70
# 50%             88.00     150.00        278.00     8.70
# 75%             89.00     170.00        295.50    10.30
# max             94.00     940.00        424.00    16.10

# %% [markdown]
# ## 1.6 Análise de Domínios Dinâmicos

# %%
# Filtrar atributos com domínio dinâmico
dominios_dinamicos = df_atributos[df_atributos['Domínio Dinâmico'] == 'Sim']

print("\n🔄 ATRIBUTOS COM DOMÍNIO DINÂMICO")
print("="*100)
print("Atributos cujos valores podem mudar ao longo do tempo (novos produtos, marcas, etc.)\n")
display(dominios_dinamicos[['Atributo', 'Tipo', 'Domínio', 'Observações']])

print(f"\n📊 Total: {len(dominios_dinamicos)} atributos com domínio dinâmico ({len(dominios_dinamicos)/len(df_atributos)*100:.1f}%)")
# Out:
# 🔄 ATRIBUTOS COM DOMÍNIO DINÂMICO
# ====================================================================================================
# Atributos cujos valores podem mudar ao longo do tempo (novos produtos, marcas, etc.)
#                        Atributo               Tipo  \
# 0                          name            Nominal
# 1                           url            Nominal
# 2                         image            Nominal
# 5                         price            Nominal
# 6                     price_usd  Numérico Contínuo
# 7                         brand            Nominal
# 44   agility and responsiveness            Nominal
# 45  fuelcell supercomp pacer v2            Nominal
#
#                                             Domínio  \
# 0                   Texto livre (nomes de produtos)
# 1   URL válida (formato: https://runrepeat.com/...)
# 2                        URL válida de imagem (CDN)
# 5                                     Texto: "$XXX"
# 6                 [0, +∞) (valores reais positivos)
# 7                           Texto (nomes de marcas)
# 44                                      Texto livre
# 45                                      Texto livre
#
#                                           Observações
# 0   Identificador único do produto. 530 valores ún...
# 1        Link para página do produto. Valores únicos.
# 2                 URL da imagem principal do produto.
# 5          Preço em formato texto. 43 valores únicos.
# 6   Preço em USD. Zero absoluto (gratuito). Razão ...
# 7          Fabricante do tênis. 26 marcas diferentes.
# 44    Avaliação de agilidade. Apenas 0.2% preenchido.
# 45  Atributo específico de produto. Apenas 0.2% pr...
# 📊 Total: 8 atributos com domínio dinâmico (17.4%)

# %% [markdown]
# ## 1.7 Resumo Executivo

# %%
print("\n" + "="*100)
print("📋 RESUMO EXECUTIVO - COMPREENSÃO DOS ATRIBUTOS")
print("="*100)

print(f"\n🔢 DIMENSÕES DO DATASET:")
print(f"  • Total de registros: {len(df):,}")
print(f"  • Total de atributos: {len(df.columns)}")

print(f"\n📊 TIPOS DE ATRIBUTOS:")
for tipo, count in tipo_counts.items():
    print(f"  • {tipo}: {count} ({count/len(df_atributos)*100:.1f}%)")

print(f"\n✅ COMPLETUDE DOS DADOS:")
print(f"  • Atributos 100% completos: {len(completude[completude['Completude (%)'] == 100])}")
print(f"  • Atributos com 80-99% de dados: {len(completude[(completude['Completude (%)'] >= 80) & (completude['Completude (%)'] < 100)])}")
print(f"  • Atributos com menos de 50% de dados: {len(completude[completude['Completude (%)'] < 50])}")

print(f"\n🎯 ATRIBUTOS PRINCIPAIS (>95% completos):")
principais = completude[completude['Completude (%)'] >= 95]['Atributo'].tolist()
for i, attr in enumerate(principais[:15], 1):
    print(f"  {i:2d}. {attr}")
if len(principais) > 15:
    print(f"  ... e mais {len(principais)-15} atributos")

print(f"\n⚠️  ATRIBUTOS ESPARSOS (<10% completos):")
esparsos = completude[completude['Completude (%)'] < 10]['Atributo'].tolist()
for i, attr in enumerate(esparsos, 1):
    pct = completude[completude['Atributo'] == attr]['Completude (%)'].values[0]
    print(f"  {i:2d}. {attr} ({pct:.1f}%)")

print(f"\n🔄 DOMÍNIOS DINÂMICOS:")
print(f"  • {len(dominios_dinamicos)} atributos com valores que podem mudar ao longo do tempo")
print(f"  • Exemplos: name, url, brand, price_usd")

print(f"\n📏 ESCALAS DE MEDIÇÃO (Atributos Numéricos):")
escalas = atributos_numericos['Escala'].value_counts()
for escala, count in escalas.items():
    print(f"  • {escala}: {count} atributos")

print("\n" + "="*100)
# Out:
# ====================================================================================================
# 📋 RESUMO EXECUTIVO - COMPREENSÃO DOS ATRIBUTOS
# ====================================================================================================
#
# 🔢 DIMENSÕES DO DATASET:
#   • Total de registros: 530
#   • Total de atributos: 46
#
# 📊 TIPOS DE ATRIBUTOS:
#   • Nominal: 25 (54.3%)
#   • Ordinal: 13 (28.3%)
#   • Numérico Contínuo: 8 (17.4%)
#
# ✅ COMPLETUDE DOS DADOS:
#   • Atributos 100% completos: 14
#   • Atributos com 80-99% de dados: 8
#   • Atributos com menos de 50% de dados: 19
#
# 🎯 ATRIBUTOS PRINCIPAIS (>95% completos):
#    1. name
#    2. breathability
#    3. image
#    4. price_usd
#    5. price
#    6. url
#    7. arch support
#    8. weight lab weight brand
#    9. brand
#   10. drop lab drop brand
#   11. strike pattern
#   12. midsole softness
#   13. difference in midsole softness in cold
#   14. heel padding durability
#   15. toebox durability
#   ... e mais 7 atributos
#
# ⚠️  ATRIBUTOS ESPARSOS (<10% completos):
#    1. midsole width - heel (6.0%)
#    2. outsole thickness (2.1%)
#    3. weight (g) (1.7%)
#    4. drop (mm) (1.7%)
#    5. flexibility of the shoe (n) (1.7%)
#    6. flexibility of the shoe (% of change) (1.7%)
#    7. flexibility of the shoe (freezer 20 min) (n) (1.5%)
#    8. longitudinal flexibility (1-5 scale, 5 being the stiffest) (1.5%)
#    9. torsional flexibility (1-5 scale, 5 being the stiffest) (0.6%)
#   10. outsole hardness (0.4%)
#   11. flexibility of the shoe (freezer 1 hour) (n) (0.2%)
#   12. longitudinal flexibility (on a 0-5 scale, 0 being the stiffest) (0.2%)
#   13. torsional flexibility (on a 0-5 scale, 0 being the stiffest) (0.2%)
#   14. agility and responsiveness (0.2%)
#   15. fuelcell supercomp pacer v2 (0.2%)
#
# 🔄 DOMÍNIOS DINÂMICOS:
#   • 8 atributos com valores que podem mudar ao longo do tempo
#   • Exemplos: name, url, brand, price_usd
#
# 📏 ESCALAS DE MEDIÇÃO (Atributos Numéricos):
#   • Razão: 8 atributos
#
# ====================================================================================================

# %% [markdown]
# ## 1.8 Exportar Tabela de Atributos

# %%
# Salvar tabela de atributos em CSV
df_atributos.to_csv('tabela_atributos_classificacao.csv', index=False, encoding='utf-8')
print("\n✅ Tabela de atributos exportada para: tabela_atributos_classificacao.csv")

# Salvar também a tabela de completude
completude.to_csv('tabela_completude_atributos.csv', index=False, encoding='utf-8')
print("✅ Tabela de completude exportada para: tabela_completude_atributos.csv")
# Out:
# ✅ Tabela de atributos exportada para: tabela_atributos_classificacao.csv
# ✅ Tabela de completude exportada para: tabela_completude_atributos.csv
